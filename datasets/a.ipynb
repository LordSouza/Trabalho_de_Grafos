# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(
    "cco_obrigatorio.xlsx", index_col="CÓDIGO"
)
df.sort_values(by="PER.")
# Out:
#                                        DISCIPLINA  PER.  CH  \
# CÓDIGO
# XDES01                 Fundamentos de Programação     1  64
# XMAC01                        Matemática Discreta     1  64
# MAT00A                                  Cálculo A     1  64
# CRSC03              Arquitetura de Computadores I     1  64
# CAHC04                          Projeto Integrado     1  32
# CMAC04                    Modelagem Computacional     2  64
# CRSC04             Arquitetura de Computadores II     2  64
# CTCO01         Algoritmos e Estruturas de Dados I     2  64
# MAT00B                                  Cálculo B     2  64
# CDES05             Programação Lógica e Funcional     2  64
# CTCO02        Algoritmos e Estruturas de Dados II     3  64
# CMAC03                       Algoritmos em Grafos     3  64
# CRSC02                      Sistemas Operacionais     3  64
# XDES04                   Engenharia de Software I     3  64
# ...

# %%
df = pd.read_excel(
    "cco_optativas.xlsx",  index_col="CÓDIGO"
)
df.sort_values(by="CÓDIGO")
# Out:
#                                       DISCIPLINA        PER.  CH  \
# CÓDIGO
# ADM03E              Empreendedorismo Tecnológico           -  48
# ADM08H   Psicologia: As relações Indivíduo-Grupo           -  48
# ADM51H      Ciências, Tecnologias e Organizações           -  48
# ADM52H           Comportamento Organizacional II           -  32
# ADM54H                        Gestão de Carreira           -  32
# ADM58H   Psicologia Organizacional e do Trabalho           -  32
# CMCO06             Modelagem Geométrica e Visual        6, 8  64
# CMCO07                       Visão Computacional           7  64
# ECOS04       Simulação e Avaliação de Desempenho           -  32
# ECOX21                 Maratona de Programação I           -  48
# ECOX22                Maratona de Programação II           -  48
# IEPG01               Empreendedorismo e Inovação           -  48
# IEPG14            Comportamento Organizacional I           -  48
# ...

# %%
df = pd.read_excel(
    "sin_obrigatorias.xlsx", index_col="CÓDIGO"
)
df.sort_values(by="PER.")
# Out:
#                                        DISCIPLINA  PER.  CH  \
# CÓDIGO
# XDES01                 Fundamentos de Programação     1  64
# IEPG22                     Administração Aplicada     1  32
# IEPG01                Empreendedorismo e Inovação     1  48
# SAHC04                          Projeto Integrado     1  64
# MAT00A                                  Cálculo A     1  64
# SAHC05      Fundamentos de Sistemas de Informação     1  64
# IEPG04                    Mapeamento de Processos     2  32
# XDES02            Programação Orientada a Objetos     2  64
# STCO01                 Algoritmos e Programação I     2  64
# XDES04                   Engenharia de Software I     2  64
# XMAC01                        Matemática Discreta     2  64
# XDES03                            Programação Web     3  64
# ECN001                                   Economia     3  48
# SDES05                  Engenharia de Software II     3  64
# ...

# %%
df = pd.read_excel(
    "sin_optativas.xlsx", index_col="CÓDIGO"
)
df.sort_values(by="CÓDIGO")
# Out:
#                                          DISCIPLINA        PER.  CH  \
# CÓDIGO
# ADM01F             Finanças: Conceitos e Aplicações        7, 9  32
# ADM08H      Psicologia: As relações Indivíduo-Grupo        7, 9  48
# ADM51H         Ciências, Tecnologias e Organizações        7, 9  48
# ADM52H              Comportamento Organizacional II        7, 9  32
# ADM54H                           Gestão de Carreira        6, 8  32
# ADM58H      Psicologia Organizacional e do Trabalho        6, 8  32
# CRSC05                          Sistemas Embarcados        6, 8  64
# ECOS04          Simulação e Avaliação de Desempenho           -  32
# ECOX21                    Maratona de Programação I        6, 8  48
# ECOX22                   Maratona de Programação II        7, 9  48
# IEPG05                     Finanças para Executivos        6, 8  48
# IEPG13                          Custos Empresariais        7, 9  48
# IEPG15  Logística e Gestão da Cadeia de Suprimentos        6, 8  32
# ...
